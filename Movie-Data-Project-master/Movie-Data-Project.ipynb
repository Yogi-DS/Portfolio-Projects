# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
movie_data_5000 = "movie_metadata.csv"
movie_5000 = pd.read_csv(movie_data_5000)

# %%
movie_5000.head().T
# Out:
#                                                                            0  \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
movie1000 = "IMDB-Movie-Data.csv"
movie_1000 = pd.read_csv(movie1000)
movie_1000.shape
movie_1000.head().T
# Out:
#                                                                     0  \
# Rank                                                                1
# Title                                         Guardians of the Galaxy
# Genre                                         Action,Adventure,Sci-Fi
# Description         A group of intergalactic criminals are forced ...
# Director                                                   James Gunn
# Actors              Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                             2014
# Runtime (Minutes)                                                 121
# Rating                                                            8.1
# Votes                                                          757074
# Revenue (Millions)                                             333.13
# Metascore                                                          76
#
# ...

# %%
all_movies=movie_1000.set_index("Title").join(movie_5000.set_index("movie_title"))

# %%
all_movies.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
all_movies.loc[:,['Metacore','imdb_score']]
# Out:
# C:\Users\andre\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                    Metacore  imdb_score
# (500) Days of Summer                    NaN         NaN
# 10 Cloverfield Lane                     NaN         NaN
# 10 Years                                NaN         NaN
# 12 Years a Slave                        NaN         NaN
# 127 Hours                               NaN         NaN
# 13 Hours                                NaN         NaN
# 1408                                    NaN         NaN
# 17 Again                                NaN         NaN
# 2012                                    NaN         NaN
# ...
